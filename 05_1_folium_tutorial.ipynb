# %% [markdown]
# ## Folium 패키지를 이용한 Interactive Map 시각화
# 대표적인 Web Map Client로는 OpenLayers, Leaflet 등이 있습니다.
# 이 중 leaflet.js를 Python에서 쓸 수 있는 Package가 folium입니다.
# 이번에는 folium을 이용해서 다양한 동적 지도 시각화를 해보겠습니다.
# https://python-visualization.github.io/folium/index.html

# %%
import geopandas as gpd

# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# folium을 이용해서 지도를 표시하는 가장 기초적인 문법은 다음과 같습니다.

# %%
# map 객체 생성
m = folium.Map(location=[37.5, 127], tiles='openstreetmap', zoom_start=10)
# map 시각화 
m

# %% [markdown]
# 배경지도로 OSM(Open Street Map)을 이용했습니다.
# 다른 배경지도는 어떤 것이 있을까요?
# https://github.com/python-visualization/folium/tree/main/folium/templates/tiles

# %%
# map 객체 생성
m = folium.Map(location=[37.5, 127], tiles='cartodbpositron', zoom_start=15)
# map 시각화 
m

# %% [markdown]
# folium에서 제공하는 배경지도만 사용할 수 있을까요?

# %%
# map 객체 생성
vworld = 'http://xdworld.vworld.kr:8080/2d/Base/service/{z}/{x}/{y}.png'
m = folium.Map(location=[37.5, 127], zoom_start=10, tiles=vworld, attr='브이월드')
# map 시각화 
m

# %% [markdown]
# 커스텀 타일맵 또는 XYZ Tiles 맵 URL은 어떻게 알 수 있을까요?

# %% [markdown]
# 기술적으로 사용할 수 있지만, Web Crawling과 같은 관점에서 법적 분쟁의 가능성이 있습니다.
# 원 제공자에게 과도한 통신 트래픽을 유발시키거나, 보안적인 문제를 일으키거나, 상용적인 재판매 등이 아닌 상황에서
# 원 제공기관의 허락을 받고 이용하는 것이 안전합니다.

# %% [markdown]
# ## 공간데이터 로딩 - 문화축제 shp

# %%
gdf = gpd.read_file('data/shp/festival_pt4326.shp', encoding='cp949')
gdf.head(3)
# Out:
#                         name organizati                    geometry
# 0  [SEMI 예천곤충엑스포] 2022예천곤충축제   경상북도 예천군  POINT (128.45865 36.82444)
# 1                     용궁순대축제   경상북도 예천군  POINT (128.27690 36.60630)
# 2                  삼강주막나루터축제   경상북도 예천군  POINT (128.29930 36.56389)

# %% [markdown]
# ## folium.Marker

# %%
# Create a map
m_2 = folium.Map(location=[36, 128], tiles='cartodbpositron', zoom_start=7)

# Add points to the map
for idx, row in gdf.iterrows():
    Marker([row.geometry.y, row.geometry.x], popup=row['name']).add_to(m_2)

# Display the map
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95cd21345a32d85dc21b313f2cca083e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95cd21345a32d85dc21b313f2cca083e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95cd21345a32d85dc21b313f2cca083e = L.map(
#                 &quot;map_95cd21345a32d85dc21b313f2cca083e&quot;,
#                 {
#                     center: [36.0, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a67ed54414399455274897abbc87cd0a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#             var marker_1d045390b88883ada4e57cbede77de61 = L.marker(
#                 [36.82443597, 128.4586463],
#                 {}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#         var popup_52bc60ab661eba26ff04eda3949e5c45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44904222e86ca0cc5be2aa8428f64870 = $(`&lt;div id=&quot;html_44904222e86ca0cc5be2aa8428f64870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[SEMI 예천곤충엑스포] 2022예천곤충축제&lt;/div&gt;`)[0];
#                 popup_52bc60ab661eba26ff04eda3949e5c45.setContent(html_44904222e86ca0cc5be2aa8428f64870);
#
#
#
#         marker_1d045390b88883ada4e57cbede77de61.bindPopup(popup_52bc60ab661eba26ff04eda3949e5c45)
#         ;
#
#
#
#
#             var marker_1803dd89af3005c974b1da1022738752 = L.marker(
#                 [36.6063001748, 128.2769007944],
#                 {}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#         var popup_48bac1eaf0c57430281baa6e5cb529b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_436b8d81e8e476261ffd20632bac38a3 = $(`&lt;div id=&quot;html_436b8d81e8e476261ffd20632bac38a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용궁순대축제&lt;/div&gt;`)[0];
#                 popup_48bac1eaf0c57430281baa6e5cb529b1.setContent(html_436b8d81e8e476261ffd20632bac38a3);
#
#
#
#         marker_1803dd89af3005c974b1da1022738752.bindPopup(popup_48bac1eaf0c57430281baa6e5cb529b1)
#         ;
#
#
#
#
#             var marker_c55edec2874ec253782b740a026463f5 = L.marker(
#                 [36.5638901566, 128.2992955068],
#                 {}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#         var popup_040be5ba45e6086a2d5c816e24dde3b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd4824d2156c6bbb2054ae1d83dc339e = $(`&lt;div id=&quot;html_bd4824d2156c6bbb2054ae1d83dc339e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;삼강주막나루터축제&lt;/div&gt;`)[0];
#                 popup_040be5ba45e6086a2d5c816e24dde3b6.setContent(html_bd4824d2156c6bbb2054ae1d83dc339e);
#
#
#
#         marker_c55edec2874ec253782b740a026463f5.bindPopup(popup_040be5ba45e6086a2d5c816e24dde3b6)
#         ;
#
#
#
#
#             var marker_db525c23453c9acb9ef25ebab052370a = L.marker(
#                 [36.6481023527, 128.4492109274],
#                 {}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#         var popup_abc37d8da2ae22fbc65a564639951c8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d81c55a22a3372a95e0d2addbea29b = $(`&lt;div id=&quot;html_36d81c55a22a3372a95e0d2addbea29b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;예천장터농산물대축제&lt;/div&gt;`)[0];
#                 popup_abc37d8da2ae22fbc65a564639951c8b.setContent(html_36d81c55a22a3372a95e0d2addbea29b);
#
#
#
#         marker_db525c23453c9acb9ef25ebab052370a.bindPopup(popup_abc37d8da2ae22fbc65a564639951c8b)
#         ;
#
#
#
#
#             var marker_f059bd60397fe3c8327ed17cae1488c2 = L.marker(
#                 [36.8888791, 128.7378251],
#                 {}
#             ).addTo(map_95cd21345a32d85dc21b313f2cca083e);
#
#
#         var popup_2cad1e5375f16c3c4b47df4b73ad6686 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3c282f58b3b696caf1c3ad665e8575c = $(`&lt;div id=&quot;html_b3c282f58b3b696caf1c3ad665e8575c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;봉화은어축제&lt;/div&gt;`)[0];
#                 popup_2cad1e5375f16c3c4b47df4b73ad6686.setContent(html_b3c282f58b3b696caf1c3ad665e8575c);
#
#
#
#         marker_f059bd60397fe3c8327ed17cae1488c2.bindPopup(popup_2cad1e5375f16c3c4b47df4b73ad6686)
#         ;
#
#
#
#
#             var marker_3c8eca54c16645472558b6505421111f = L.marker(
#                 [

# %% [markdown]
# ## folium.plugins.MarkerCluster

# %%
# Create the map
m_3 = folium.Map(location=[36, 128], tiles='cartodbpositron', zoom_start=7)

# Add points to the map
mc = MarkerCluster()
for idx, row in gdf.iterrows():
    mc.add_child(Marker([row.geometry.y, row.geometry.x]))
m_3.add_child(mc)

# Display the map
m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_184c515177fcea670346087c99659679 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_184c515177fcea670346087c99659679&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_184c515177fcea670346087c99659679 = L.map(
#                 &quot;map_184c515177fcea670346087c99659679&quot;,
#                 {
#                     center: [36.0, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bd3e034c871fa970fedaf9024649b83 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_184c515177fcea670346087c99659679);
#
#
#             var marker_cluster_e26c0f88187843a4075d91898b07f885 = L.markerClusterGroup(
#                 {}
#             );
#             map_184c515177fcea670346087c99659679.addLayer(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_860df2f99946ec2c24cd4918934a7704 = L.marker(
#                 [36.82443597, 128.4586463],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_fddb35573349b1f68da2d14ab309e3d0 = L.marker(
#                 [36.6063001748, 128.2769007944],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_bc38580e68b796f501c3ce4a9fe26c44 = L.marker(
#                 [36.5638901566, 128.2992955068],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_f55967df775483f67a47753c98630ede = L.marker(
#                 [36.6481023527, 128.4492109274],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_e72fc7169760daa72fcb9f78df3f4130 = L.marker(
#                 [36.8888791, 128.7378251],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_20720a1a49a804a9c3acfdba9cecbf8e = L.marker(
#                 [36.8888791, 128.7378251],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_019233bd46c169c96aa1dd2fb5141df4 = L.marker(
#                 [36.13824055, 128.088634],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_a829fff8d4aca7b88a4bf92fc717f69d = L.marker(
#                 [37.38979099, 126.7812554],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_fc6d6e71becf6b0db29aee0dab302309 = L.marker(
#                 [37.882374, 127.73137],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_c70375501f7c5b63c3ee05104d1a9013 = L.marker(
#                 [37.921016, 127.720105],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_857ca748d4c02e008ce498a5f58e20a7 = L.marker(
#                 [37.921016, 127.720105],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_08e39bcb70a5040cf234ec9d3a4c6525 = L.marker(
#                 [37.873097, 127.727838],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_6f31d5f2e74651f4831d0c58c795a9bb = L.marker(
#                 [37.873097, 127.727838],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_409b9ea8fb2581d04091afb45c176392 = L.marker(
#                 [37.884815, 127.724649],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_abfd915ab7c7012f24ef4aba95e122c9 = L.marker(
#                 [37.5230127, 129.1143227],
#                 {}
#             ).addTo(marker_cluster_e26c0f88187843a4075d91898b07f885);
#
#
#             var marker_79b51e2c74dec8265b1d2218cd684ce8 = L.marker(
#                 [37.172348442, 127.0489503649],
#                 {}
#             ).addTo(marker_clu

# %% [markdown]
# ## Heatmaps

# %%
gdf['lat'] = gdf.geometry.y
gdf['lon'] = gdf.geometry.x

# %%
# Create a base map
m_4 = folium.Map(location=[36, 128], tiles='cartodbdark_matter', zoom_start=7)

# Add a heatmap to the base map
HeatMap(data=gdf[['lat', 'lon']], radius=10).add_to(m_4)

# Display the map
m_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ca764cdbb489378d55b4f804fa4cea8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ca764cdbb489378d55b4f804fa4cea8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ca764cdbb489378d55b4f804fa4cea8 = L.map(
#                 &quot;map_1ca764cdbb489378d55b4f804fa4cea8&quot;,
#                 {
#                     center: [36.0, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d17e1da500158b7dafed81f6aa16f76d = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ca764cdbb489378d55b4f804fa4cea8);
#
#
#             var heat_map_ea9e4028d7a96d781de4436eb0fe545d = L.heatLayer(
#                 [[36.82443597, 128.4586463], [36.6063001748, 128.2769007944], [36.5638901566, 128.2992955068], [36.6481023527, 128.4492109274], [36.8888791, 128.7378251], [36.8888791, 128.7378251], [36.13824055, 128.088634], [37.38979099, 126.7812554], [37.882374, 127.73137], [37.921016, 127.720105], [37.921016, 127.720105], [37.873097, 127.727838], [37.873097, 127.727838], [37.884815, 127.724649], [37.5230127, 129.1143227], [37.172348442, 127.0489503649], [35.23893658, 126.8973084], [35.18482092, 127.000917], [35.18482092, 127.000917], [35.14863464, 126.985744], [35.36265187, 126.4359383], [35.19967508, 126.5500476], [35.63424081, 129.3289893], [35.49577039, 129.4306152], [35.5027537, 129.3807899593], [35.5500212, 129.266004], [35.5566794, 129.320056], [35.548823, 129.291263], [35.55011074, 129.3101786], [35.548823, 129.291263], [35.53098415, 129.2939195], [35.53098415, 129.2939195], [35.548823, 129.291263], [35.53794728, 129.3112566], [35.548823, 129.291263], [35.069718, 126.8375167], [35.14019141, 126.9163647], [35.6867346, 128.7251449], [35.65498121, 128.7372391], [35.64838523, 128.7186823], [35.64838523, 128.7186823], [35.64725258, 128.7339993], [37.49551123, 126.8882891], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.87155388, 128.6012201], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [37.733386, 127.034128], [37.733386, 127.034128], [37.745147, 127.106129], [37.73517724, 127.0338894], [35.09241574, 126.8386216], [35.140085, 126.9157016], [35.149407, 126.7951682], [35.06581966, 126.761073], [35.16426707, 126.9160455], [35.12316806, 126.9166047], [35.22222807, 126.8442514], [35.30173083, 128.9895949], [35.3776261151, 129.1434298545], [35.4116158294, 129.1822946326], [36.91240318, 128.4706212], [36.99451393, 128.6811773], [36.92847353, 128.5834337], [36.732962, 128.621224], [34.84715495, 128.423489], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [35.8692058, 128.5954708], [35.8692058, 128.5954708], [35.8692058, 128.5954708], [35.8692058, 128.5954708], [35.8692058, 128.5954708], [35.8692058, 128.5954708], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.86932522, 128.6061572], [35.88681058, 128.6360751], [35.88681058, 128.6360751], [35.87232184, 128.5592911], [35.84594995, 128.5975989], [35.84594995, 128.5975989], [35.84594995, 128.5975989], [35.8856843, 128.5827802], [35.8856843, 128.5827802], [35.85820008, 128.6306298], [35.82991524, 128.5328365], [35.77466287, 128.4313916], [35.86339725, 128.5965647], [35.86339725, 128.5965647], [37.39013727, 126.9613302], [37.39013727, 126.9613302], [37.4194056, 126.925606], [37.39013727, 126.9613302], [37.40461526, 126.8961574], [37.39013727, 126.9613302], [37.38458779, 126.9313651], [37.39013727, 126.9613302], [37.40461526, 126.8961574], [37.39013727, 126.9613302], [36.76160207, 128.0769905], [36.7715572, 128.3153048], [36.76160207, 128.0769905], [35.10362715, 129.0261809], [35.09862035, 129.0287588], [35.0966394, 129.0305933], [35.0995432, 129.0314651], [37.38024298, 128.6602287], [37.516751, 128.2137117549], [37.58392059, 128.1502908], [36.3030708, 127.575808], [37.1369797, 128.2065521], [36.49335597, 127.5964464], [36.16401625, 12

# %% [markdown]
# ## Choropleth maps - 단계구분도

# %%
shp_path = 'data/shp/NGII_CDM_행정경계(시도)/Z_NGII_N3A_G0010000.shp'
sido_gdf = gpd.read_file(shp_path, encoding='cp949')

# %%
sido_gdf['area'] = sido_gdf.geometry.area / 1000000
sido_gdf
# Out:
#                  UFID        BJCD     NAME    DIVI  SCLS  FMTA  \
# 0   ARB0100000000001E  5000000000  제주특별자치도  HJD004  None  None
# 1   ARB0100000000002F  4800000000     경상남도  HJD004  None  None
# 2   ARB0100000000003G  4700000000     경상북도  HJD004  None  None
# 3   ARB0100000000004H  4600000000     전라남도  HJD004  None  None
# 4   ARB0100000000005I  4500000000     전라북도  HJD004  None  None
# 5   ARB0100000000006J  4400000000     충청남도  HJD004  None  None
# 6   ARB0100000000007K  4300000000     충청북도  HJD004  None  None
# 7   ARB0100000000008L  4200000000      강원도  HJD004  None  None
# 8   ARB0100000000009M  4100000000      경기도  HJD004  None  None
# 9   ARB010000000000AN  3600000000  세종특별자치시  HJD002  None  None
# 10  ARB010000000000BO  3100000000    울산광역시  HJD003  None  None
# 11  ARB010000000000CP  3000000000    대전광역시  HJD003  None  None
# 12  ARB010000000000DQ  2900000000    광주광역시  HJD003  None  None
# 13  ARB010000000000ER  2800000000    인천광역시  HJD003  None  None
# 14  ARB010000000000FS  2700000000    대구광역시  HJD003  None  None
# 15  ARB010000000000GT  2600000000    부산광역시  HJD003  None  None
# 16  ARB010000000000HU  1100000000    서울특별시  HJD002  None  None
#
#                                              geometry          area
# 0   MULTIPOLYGON (((932629.315 1508520.449, 932629...   1862.098047
# 1   MULTIPOLYGON (((1049231.579 1666542.963, 10492...  10538.923224
# 2   MULTIPOLYGON (((1163496.075 1906689.767, 11635...  19022.614443
# 3   MULTIPOLYGON (((898759.456 1670482.743, 898760...  12402.307866
# 4   MULTIPOLYGON (((953538.952 1794637.930, 953543...   8078.157375
# 5   MULTIPOLYGON (((911872.862 1896389.683, 912719...   8237.703818
# 6   POLYGON ((1042565.907 1917797.156, 1042636.422...   7407.049412
# 7   MULTIPOLYGON (((1087041.227 2043079.071, 10871...  14731.845937
# 8   MULTIPOLYGON (((924321.934 1910868.490, 924328...   8898.121339
# 9   POLYGON ((970186.553 1859546.542, 970194.862 1...    464.560339
# 10  MULTIPOLYGON (((1149453.995 1748579.301, 11494...   1058.417267
# 11  POLYGON ((989769.987 1833514.258, 989793.674 1...    539.711321
# 12  POLYGON ((932713.054 1696169.621, 932794.248 1...    497.901789
# 13  MULTIPOLYGON (((925527.033 1960166.877, 925537...    666.107521
# 14  POLYGON ((1107724.713 1780546.645, 1107795.177...    876.725196
# 15  MULTIPOLYGON (((1155478.996 1710805.326, 11555...    768.101061
# 16  POLYGON ((969432.943 1948411.747, 969426.225 1...    605.183193

# %%
sido_gdf4326 = sido_gdf.to_crs(epsg=4326)

# %%
# Create a base map
m_5 = folium.Map(location=[35.7, 128], tiles='cartodbpositron', zoom_start=7)

myscale = (sido_gdf4326['area'].quantile((0, 0.25, 0.5, 0.75, 1))).tolist()

# Add a choropleth map to the base map
m_5.choropleth(
    geo_data=sido_gdf4326, 
    name='Choropleth',    
    data=sido_gdf4326, 
    columns=('BJCD', 'area'),           
    key_on='feature.properties.BJCD', 
    fill_color='YlGnBu',
    threshold_scale=myscale,
    fill_opacity=0.7,
    line_opacity=0.1,
    legend_name='시도별 면적',
    smooth_factor=1
    )

# Display the map
m_5

# %% [markdown]
# 시도 행정구역을 빠르게 시각화하기 위해서는 어떤 방법을 적용할 수 있을까요?

# %% [markdown]
# ## Bubble maps

# %%
sido_gdf4326_pt = sido_gdf4326.copy()
sido_gdf4326_pt['geometry'] = sido_gdf4326_pt.centroid
sido_gdf4326_pt.head()
# Out:
# C:\Users\thlee\AppData\Local\Temp\ipykernel_18504\3172568690.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   sido_gdf4326_pt['geometry'] = sido_gdf4326_pt.centroid
#                 UFID        BJCD     NAME    DIVI  SCLS  FMTA  \
# 0  ARB0100000000001E  5000000000  제주특별자치도  HJD004  None  None
# 1  ARB0100000000002F  4800000000     경상남도  HJD004  None  None
# 2  ARB0100000000003G  4700000000     경상북도  HJD004  None  None
# 3  ARB0100000000004H  4600000000     전라남도  HJD004  None  None
# 4  ARB0100000000005I  4500000000     전라북도  HJD004  None  None
#
#                      geometry          area
# 0  POINT (126.55437 33.38752)   1862.098047
# 1  POINT (128.26134 35.32324)  10538.923224
# 2  POINT (128.74880 36.34862)  19022.614443
# 3  POINT (126.90007 34.87395)  12402.307866
# 4  POINT (127.14180 35.71586)   8078.157375

# %%
# Create a base map
m_6 = folium.Map(location=[35.7, 128], tiles='cartodbpositron', zoom_start=7)

def color_producer(val):
    if val <= 10 :
        return 'forestgreen'
    else:
        return 'darkred'

for idx, row in sido_gdf4326_pt.iterrows():
    Circle(
        location=[row.geometry.y, row.geometry.x],
        radius=row['area'] * 3,
        fill=True,
        fill_color=color_producer(row['area'] / 1000 ),
        color=color_producer(row['area'] / 1000 ),
        popup=row['NAME'] + " : " + str(round(row['area'],0))
    ).add_to(m_6) 

# Display the map
m_6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4620ea5b57defa047a8d25f327ea5b22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4620ea5b57defa047a8d25f327ea5b22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4620ea5b57defa047a8d25f327ea5b22 = L.map(
#                 &quot;map_4620ea5b57defa047a8d25f327ea5b22&quot;,
#                 {
#                     center: [35.7, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b703db6db69d898df5378945ed7850c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4620ea5b57defa047a8d25f327ea5b22);
#
#
#             var circle_872c3fd32df2e447679551ae5765cc29 = L.circle(
#                 [33.38752244301239, 126.55437202041902],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;forestgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;forestgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5586.294140385992, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4620ea5b57defa047a8d25f327ea5b22);
#
#
#         var popup_6bfce0eaf12a4da19c18754115cab442 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ff3e3c5be79e57ed250c997ee8beb29 = $(`&lt;div id=&quot;html_7ff3e3c5be79e57ed250c997ee8beb29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 : 1862.0&lt;/div&gt;`)[0];
#                 popup_6bfce0eaf12a4da19c18754115cab442.setContent(html_7ff3e3c5be79e57ed250c997ee8beb29);
#
#
#
#         circle_872c3fd32df2e447679551ae5765cc29.bindPopup(popup_6bfce0eaf12a4da19c18754115cab442)
#         ;
#
#
#
#
#             var circle_ffa99ed8a3f33b755eb4ab669ed8b587 = L.circle(
#                 [35.32324143720046, 128.26133728441968],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31616.76967138113, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4620ea5b57defa047a8d25f327ea5b22);
#
#
#         var popup_ebeb886d9f4ad81e22b4c32ec391733d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65d8978920b99c61898fa9e1536e0aca = $(`&lt;div id=&quot;html_65d8978920b99c61898fa9e1536e0aca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경상남도 : 10539.0&lt;/div&gt;`)[0];
#                 popup_ebeb886d9f4ad81e22b4c32ec391733d.setContent(html_65d8978920b99c61898fa9e1536e0aca);
#
#
#
#         circle_ffa99ed8a3f33b755eb4ab669ed8b587.bindPopup(popup_ebeb886d9f4ad81e22b4c32ec391733d)
#         ;
#
#
#
#
#             var circle_ec3d75ffc4012c03974657d2ec18bcac = L.circle(
#                 [36.348620283470645, 128.74879869208803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 57067.8433302546, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4620ea5b57defa047a8d25f327ea5b22);
#
#
#         var popup_a27b986b8a79bf650ddd77293ac924ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea62067045565a0168c248065731c215 = $(`&lt;div id=&quot;html_ea62067045565a0168c248065731c215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경상북도 : 19023.0&lt;/div&gt;`)[0];
#                 popup_a27b986b8a79bf650ddd77293ac924ac.setContent(html_ea62067045565a0168c248065731c215);
#
#
#
#         circle_ec3d75ffc4012c03974657d2ec18bcac.bindPopup(popup_a27b986b8a79bf650ddd77293ac924ac)
#         ;
#
#
#
#
#             var circle_b8c543c6b8ae213cccefa7fc78e55fd9 = L.circle(
#                 [34.87394838837525, 126.90007032873007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&

# %% [markdown]
# ## 수고 많으셨습니다!!!
